# %%
# %pip install -q google-generativeai
# %pip install grpcio
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: grpcio in /home/chuongmep/.local/lib/python3.10/site-packages (1.59.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as palm
# add your token here
palm.configure(api_key="<Put your key>")
# see the list of models
models = [
    m for m in palm.list_models() if "generateText" in m.supported_generation_methods
]

for m in models:
    print(f"Model Name: {m.name}")
model = models[0].name
print("Model Name: ", model)

# Generate text
prompt = "What is BIM ?"
completion = palm.generate_text(
    model=model,
    prompt=prompt,
    temperature=0.3,
    # The maximum length of the response
    max_output_tokens=800,
)

print(completion.result)
# Out:
# Model Name: models/text-bison-001
# Model Name:  models/text-bison-001
# Building Information Modelling (BIM) is a digital representation of physical and functional characteristics of a building. It is a shared knowledge resource for information about a facility, providing a coordinated means of managing design, construction, operation and maintenance of a facility throughout its lifecycle.
#
# BIM is a process that uses 3D models to create a digital representation of a building. This model can be used to plan, design, construct, and maintain a building. BIM is not just a 3D model; it is a database that contains information about the building, such as its dimensions, materials, and components. This information can be used to create a variety of plans and documents, such as floor plans, elevations, and sections. BIM can also be used to create simulations of how a building will perform under different conditions, such as how it will withstand wind loads or how much energy it will use.
#
# BIM is a powerful tool that can help to improve the design, construction, and maintenance of buildings. It can help to reduce costs, improve safety, and increase efficiency. BIM is becoming increasingly popular in the construction industry, and it is expected to become the standard for building design and construction in the future.

# %%
# pip freeze to get the list of packages used in the notebook
# %pip freeze
# Out:
# aiohttp==3.8.5
# aiosignal==1.3.1
# altair==5.1.1
# annotated-types==0.6.0
# anyio==3.7.1
# asttokens==2.4.0
# async-timeout==4.0.3
# attrs==23.1.0
# audio-recorder-streamlit==0.0.8
# backcall==0.2.0
# backoff==2.2.1
# bcrypt==4.0.1
# beautifulsoup4==4.12.2
# blinker==1.4
# cachetools==5.3.1
# certifi==2023.7.22
# cffi==1.16.0
# chardet==5.2.0
# charset-normalizer==3.2.0
# chroma-hnswlib==0.7.3
# chromadb==0.4.14
# click==8.1.7
# colorama==0.4.6
# coloredlogs==15.0.1
# comm==0.1.4
# command-not-found==0.3
# contourpy==1.1.1
# cryptography==41.0.4
# cycler==0.12.1
# dataclasses-json==0.6.1
# dbus-python==1.2.18
# debugpy==1.8.0
# decorator==5.1.1
# distro==1.7.0
# distro-info===1.1build1
# emoji==2.8.0
# entrypoints==0.4
# exceptiongroup==1.1.3
# executing==2.0.0
# Faker==19.10.0
# fastapi==0.103.2
# favicon==0.7.0
# ffprobe==0.5
# filelock==3.12.4
# filetype==1.2.0
# flatbuffers==23.5.26
# fonttools==4.43.1
# frozenlist==1.4.0
# fsspec==2023.9.2
# gitdb==4.0.10
# GitPython==3.1.35
# google-ai-generativelanguage==0.3.3
# google-api-core==2.12.0
# google-auth==2.23.3
# google-generativeai==0.2.1
# googleapis-common-protos==1.61.0
# greenlet==3.0.0
# grpcio==1.59.0
# grpcio-status==1.59.0
# h11==0.14.0
# htbuilder==0.6.2
# httplib2==0.20.2
# httptools==0.6.0
# huggingface-hub==0.17.3
# humanfriendly==10.0
# idna==3.4
# importlib-metadata==6.8.0
# importlib-resources==6.1.0
# ipykernel==6.25.2
# ipython==8.16.1
# jedi==0.19.1
# jeepney==0.7.1
# Jinja2==3.1.2
# joblib==1.3.2
# jsonpatch==1.33
# jsonpointer==2.4
# jsonschema==4.19.0
# jsonschema-specifications==2023.7.1
# jupyter_client==8.4.0
# jupyter_core==5.4.0
# keyring==23.5.0
# kiwisolver==1.4.5
# langchain==0.0.313
# langdetect==1.0.9
# langsmith==0.0.43
# launchpadlib==1.10.16
# lazr.restfulclient==0.14.4
# lazr.uri==1.0.6
# lxml==4.9.3
# Markdown==3.5
# markdown-it-py==3.0.0
# markdownlit==0.0.7
# MarkupSafe==2.1.3
# marshmallow==3.20.1
# matplotlib==3.8.0
# matplotlib-inline==0.1.6
# mdurl==0.1.2
# monotonic==1.6
# more-itertools==8.10.0
# mpmath==1.3.0
# multidict==6.0.4
# mypy-extensions==1.0.0
# nest-asyncio==1.5.8
# netifaces==0.11.0
# nltk==3.8.1
# numpy==1.25.2
# oauthlib==3.2.0
# onnxruntime==1.16.1
# openai==0.28.0
# overrides==7.4.0
# packaging==23.1
# pandas==2.1.0
# parso==0.8.3
# pdf2image==1.16.3
# pdfminer==20191125
# pdfminer.six==20221105
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==10.0.1
# platformdirs==3.11.0
# posthog==3.0.2
# prompt-toolkit==3.0.39
# proto-plus==1.22.3
# protobuf==4.24.3
# psutil==5.9.5
# ptyprocess==0.7.0
# pulsar-client==3.3.0
# pure-eval==0.2.2
# pyarrow==13.0.0
# pyasn1==0.5.0
# pyasn1-modules==0.3.0
# pycparser==2.21
# pycryptodome==3.19.0
# pydantic==2.4.2
# pydantic_core==2.10.1
# pydeck==0.8.0
# pydub==0.25.1
# Pygments==2.16.1
# PyGObject==3.42.1
# PyJWT==2.3.0
# pymdown-extensions==10.3
# Pympler==1.0.1
# pyparsing==2.4.7
# PyPika==0.48.9
# python-apt==2.4.0+ubuntu1
# python-dateutil==2.8.2
# python-dotenv==1.0.0
# python-iso639==2023.6.15
# python-magic==0.4.27
# pytz==2023.3.post1
# pytz-deprecation-shim==0.1.0.post0
# PyYAML==5.4.1
# pyzmq==25.1.1
# rapidfuzz==3.4.0
# referencing==0.30.2
# regex==2023.10.3
# requests==2.31.0
# rich==13.6.0
# rpds-py==0.10.2
# rsa==4.9
# SecretStorage==3.3.1
# six==1.16.0
# smmap==5.0.0
# sniffio==1.3.0
# sounddevice==0.4.6
# soundfile==0.12.1
# soupsieve==2.5
# SQLAlchemy==2.0.22
# st-annotated-text==4.0.1
# stack-data==0.6.3
# starlette==0.27.0
# streamlit==1.27.2
# streamlit-audiorecorder==0.0.3.post1
# streamlit-camera-input-live==0.2.0
# streamlit-card==0.0.61
# streamlit-embedcode==0.1.2
# streamlit-extras==0.3.4
# streamlit-faker==0.0.2
# streamlit-image-coordinates==0.1.6
# streamlit-keyup==0.2.0
# streamlit-toggle-switch==1.0.2
# streamlit-vertical-slider==1.0.2
# sympy==1.12
# systemd-python==234
# tabulate==0.9.0
# tenacity==8.2.3
# tokenizers==0.14.1
# toml==0.10.2
# toolz==0.12.0
# tornado==6.3.3
# tqdm==4.66.1
# traitlets==5.11.2
# typer==0.9.0
# typing-inspect==0.9.0
# typing_extensions==4.8.0
# tzdata==2023.3
# tzlocal==4.3.1
# ubuntu-advantage-tools==8001
# ufw==0.36.1
# unattended-upgrades==0.1
# unstructured==0.10.21
# urllib3==2.0.4
# uvicorn==0.23.2
# uvloop==0.17.0
# validators==0.22.0
# wadllib==1.3.6
# watchdog==3.0.0
# watchfiles==0.20.0
# wcwidth==0.2.8
# websockets==11.0.3
# yarl==1.9.2
# zipp==1.0.0
# Note: you may need to restart the kernel to use updated packages.
